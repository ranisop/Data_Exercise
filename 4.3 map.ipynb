# %% [markdown]
# ### 4.3 map

# %%
import pandas as pd
raw_total = pd.read_excel('./data/jeju_crawling_raw.xlsx')
raw_total.head()
# Out:
#    Unnamed: 0                                            content        date  \
# 0           0  (광고)지만 찐로컬맛집!!제주도민들의 흑돼지픽🎯'한라축산정육식당'🙏착한가격에 신선함...  2020-10-06
# 1           1  산도롱1오늘 뭐먹지 고민이신분산도롱맨도롱으로 🍜모두모두 모이세요!100% 도가니 육...  2020-10-07
# 2           4  광고★성산일출봉이 다보여!성산일출봉도 보이고성산일출봉 파도소리도 드리고2인49,00...  2020-10-06
# 3           5  제주 유일무이 고기국수 맛집🍜100%도가니 육수를 우려 깊은맛이 일품!!호로록 한입...  2020-10-05
# 4           6  제주도맛집 검색하다 찾은 대박맛집!.제주도 "오전 열한시".다른분께서 리뷰하신거 보...  2020-10-07
#
#     like place                                               tags
# 0      0   NaN  ['#제주흑돼지맛집', '#제주도흑돼지맛집', '#제주시맛집', '#제주공항근처맛집...
# 1      0   NaN  ['#제주도맛집', '#제주맛집', '#제주도고기국수', '#성산맛집', '#광치기...
# 2  1,174   NaN  ['#제주맛집', '#제주도맛집', '#성산맛집', '#서귀포맛집', '#성산일출봉...
# 3  1,256   NaN  ['#제주도맛집', '#제주맛집', '#제주도고기국수', '#성산일출봉맛집', '#...
# 4      0   NaN  ['#광고입니다', '#서귀포맛집', '#중문맛집', '#제주도맛집', '#제주맛집...

# %%
# 위치 정보 가져오기
location_counts = raw_total['place'].value_counts()
location_counts
# Out:
# Jeju                                  54
# 제주도                                   40
# Jeju-do                               39
# 환상의 섬 Jeju Island                     15
# 제주 협재 해수욕장                            10
# 푸른섬 제주도                                9
# Jeju Island                            9
# 제주도 Jeju Island                        9
# Seogwipo                               8
# 제주도 애월읍                                8
# 제주도 곽지해수욕장                             7
# 안돌오름                                   7
# 고래배꼽                                   7
# 모알보알                                   6
# Seogwipo, Jeju Island, South Korea     5
# The Shilla Jeju                        5
# 한담해안산책로                                4
# Cafè 새빌                                4
# 새별오름                                   4
# 금악오름                                   4
# Jeju Island, South Korea - 제주도         4
# 사이카레                                   4
# 제주 아침미소목장                              3
# Gwangju                                3
# 카페 마노르블랑 제주                            3
# 제주귀더크                                  3
# 아카렌가                                   3
# 이호테우해변                                 3
# 도두해안도로                                 3
# D&department JEJU by Arario            3
#                                       ..
# 한라닭강정                                  1
# 마시안해변                                  1
# 사랑받는 중                                 1
# 여유로이                                   1
# 애플망고1947                               1
# 이응게스트하우스                               1
# 명진전복                                   1
# Pizzeria Mano                          1
# 평대홀라인                                  1
# 천연불맛 불쇼 미온당                            1
# 송악산 둘레길                                1
# 애월하미                                   1
# 유루유루                                   1
# 첨성대                                    1
# 타무라                                    1
# 물질식육식당                                 1
# 마레벤또                                   1
# 오설록티뮤지엄                                1
# 제주시동문시장                                1
# HOTEL Toscana                          1
# 논짓물식당                                  1
# 카페, 그 해 여름                             1
# 조천수산                                   1
# 디앤디파트먼트 제주                             1
# 제주유리박물관                                1
# 전주도                                    1
# Jeju Isand                             1
# 독서의입구                                  1
# 돈이랑 본점                                 1
# 블루모모                                   1
# Name: place, Length: 385, dtype: int64

# %%
# 등록된 위치 정보별 빈도수 데이터 -> dataframe 변환
location_counts_df = pd.DataFrame(location_counts)
location_counts_df.head()
# Out:
#                    place
# Jeju                  54
# 제주도                   40
# Jeju-do               39
# 환상의 섬 Jeju Island     15
# 제주 협재 해수욕장            10

# %%
# 위치 정보의 빈도수 데이터 저장
location_counts_df.to_excel('./data/jeju_location_counts.xlsx')

# %%
# 위치 정보의 종류 확인
locations = list(location_counts.index)
locations
# Out:
# ['Jeju',
#  '제주도',
#  'Jeju-do',
#  '환상의 섬 Jeju Island',
#  '제주 협재 해수욕장',
#  '푸른섬 제주도',
#  'Jeju Island',
#  '제주도 Jeju Island',
#  'Seogwipo',
#  '제주도 애월읍',
#  '제주도 곽지해수욕장',
#  '안돌오름',
#  '고래배꼽',
#  '모알보알',
#  'Seogwipo, Jeju Island, South Korea',
#  'The Shilla Jeju',
#  '한담해안산책로',
#  'Cafè 새빌',
#  '새별오름',
#  '금악오름',
#  'Jeju Island, South Korea - 제주도',
#  '사이카레',
#  '제주 아침미소목장',
#  'Gwangju',
#  '카페 마노르블랑 제주',
#  '제주귀더크',
#  '아카렌가',
#  '이호테우해변',
#  '도두해안도로',
#  'D&department JEJU by Arario',
#  '한림공원 Hallimpark',
#  '용눈이오름',
#  '용머리해안',
#  '제주 함덕 서우봉 해변',
#  'One and only - 원앤온리 제주',
#  '월정리해변',
#  '제주시민속오일시장',
#  '사려니숲길',
#  '그계절',
#  '광치기해변',
#  '제주 서귀포',
#  '미남미녀',
#  '마녀상회',
#  'Jeju901',
#  '곱을락연어',
#  '산방산근처',
#  "협재화덕 도나토스_Donato's",
#  '서귀다원',
#  '금능해수욕장',
#  'Umu Pudding , 우무',
#  '상효원 수목원',
#  '우도',
#  '허니문하우스',
#  '제주김만복',
#  '젬스톤',
#  '합정 어딘가',
#  '하이엔드 제주',
#  '오후새우시',
#  '제주신화월드 Jeju Shinhwa World',
#  '우도 牛岛 Udo Island, South Korea',
#  '북촌에 가면',
#  '섭지코지 (Seopjikoji)',
#  '함덕해수욕장',
#  '애월해안도로',
#  '서귀포 치유의 숲',
#  'Hidden Cliff / 히든 클리프',
#  '울트라마린',
#  '도두봉',
#  '모뉴에트',
#  '88 Burger',
#  '큰엉해안경승지',
#  '제주맛집',
#  '블루라군다이브-bluelagoondive',
#  '아부오름',
#  '빛의 벙커 Bunker de Lumières',
#  '숙성도',
#  '신창풍차해안도로',
#  '드르쿰다',
#  '제주도 서귀포',
#  'Enough, 이너프',
#  'Vadada 바다다',
#  '제주도 우도',
#  'Harmduck Beach in Jeju Island',
#  'Cafe yuzu',
#  'Daegu, South Korea',
#  'Veke',
#  'Oedo339',
#  '항파두리 항몽유적지',
#  'Gwangju, South Korea',
#  '아르떼뮤지엄 Arte Museum',
#  '아줄레주',
#  '별돈별',
#  '미스틱 3도',
#  '제주시 조천읍 와산리',
#  '곽지해수욕장',
#  '베케',
#  'moon_064_744_9901',
#  'Seongsan Ilchulbong',
#  '금오름',
#  '카페아오오 cafe ooo',
#  '따라비오름',
#  '미미슈',
#  '제주도 한림',
#  'Jeju-Island',
#  'Gongbech.공백',
#  '월정길',
#  '함덕골목해장국',
#  '여름문구사',
#  '제제댁',
#  '성읍녹차마을 영농조합법인',
#  '비밀의숲',
#  '숨비나리',
#  '스튜디오 쿠나',
#  '울산',
#  '볼수록 제주',
#  '명랑스낵',
#  'woomoo_cafe',
#  '함덕487',
#  '제주 산방산',
#  '濟州國際機場 - 제주국제공항 - Jeju Airport',
#  '𝐋𝐨𝐧𝐠𝐥𝐢𝐯𝐞 - 롱리브',
#  'Busan, South Korea',
#  '인그리드',
#  '다찌',
#  'Joanne Bear Museum',
#  '이중섭 거리',
#  '한담공원',
#  '보름우스테이',
#  '산굼부리',
#  '노리매',
#  '제주도 삼미횟집',
#  '구쟁기가김밥속에',
#  '소봉식당',
#  '글라글라하와이 - GlaGla Hawaii',
#  '늘봄흑돼지',
#  '제주시 구좌읍 평대리',
#  '카페록록 Loklok',
#  '시흥배곧신도시',
#  '인손',
#  '연돈',
#  'Hotel Seogwipean 호텔 서귀피안',
#  'L’apéro - 라페로',
#  '송당리 풍림다방',
#  '곽지횟집',
#  '세화해변',
#  '오라방',
#  '알뜨르비행장',
#  'Jinju',
#  '서정다이브',
#  '금능상회',
#  '귤밭상점',
#  '제주도푸른밤',
#  '골목카페 옥수',
#  '제주 애월읍',
#  '아끈다랑쉬오름',
#  '서귀포',
#  '윤네일&김뷰티',
#  '연 과자점',
#  '제주도 도두봉',
#  '서퍼들의 천국 중문해수욕장',
#  '레이지펌프',
#  '서귀포혁신도시',
#  '돼지굽는정원',
#  '토니토니 제주 - 카페,피자&파스타,게스트하우스',
#  '아름다운 섬 제주도~~오',
#  'Jeju Island, Korea',
#  '델문도 제주 카페 Cafe Delmoondo',
#  '모모샌드',
#  '도민상회월정점',
#  '르미에르제주',
#  '정물오름',
#  '산지해장국',
#  '베이힐풀앤빌라 Bayhill Pool&Villa',
#  'Indigoterie',
#  '인생밥집',
#  '휴일로',
#  '봄이옵니다플라워',
#  '가시아방',
#  '홀리싯',
#  '제주 월령선인장 군락지',
#  '서귀포시 꼬지사께',
#  '백약이 오름',
#  '카이로스 제주',
#  '램하우스',
#  '다다의 작은공간',
#  '공간사진관',
#  'Daejeon',
#  '한라산 성판악 입구',
#  '제주도 해안도로',
#  'Jeju Rail Bike',
#  'Mooasis',
#  '추억 속',
#  '제주무스비',
#  '하나의식탁',
#  '그리운바다성산포',
#  '서귀포 매일올레시장',
#  '두물머리',
#  '에코랜드',
#  '새미은총의동산',
#  '제주도 토스카나호텔',
#  'Gyeongju, Korea',
#  '미친부엌',
#  'Lazzzy coffee',
#  '너와의첫여행',
#  '아우내순대제주',
#  '노고로시',
#  'Cookhoon쿠쿤',
#  '쇠소깍 수우동',
#  '제주스쿠버스쿨',
#  '제마닭',
#  '문쏘',
#  'Saturdayisland',
#  '제주도 함덕해수욕장',
#  '서우봉 둘레길',
#  '성산일출봉 Seongsan Sunrise Peak',
#  '머체왓숲길',
#  '제주제트',
#  'Jeju, Korea',
#  '김녕',
#  'Gwakji Gwamul Beach',
#  '난산리사무소',
#  'Seoul, Korea',
#  '제주 함덕해변',
#  '담양소예르',
#  '여의도한강공윈',
#  '세부 막탄섬에서',
#  '쥬데마르카 Jeu De Markaa',
#  '제주시 조천읍 선흘리',
#  'Muju',
#  '돌카롱',
#  '랜디스도넛',
#  '썬샤인워크',
#  '김해공항',
#  '제주도 새별오름',
#  '김포공항',
#  '와락 게스트하우스',
#  '뱃도새기',
#  '스누피가든',
#  '폼포코식당',
#  '퍼시픽랜드 - Pacific Land JEJU',
#  '돌담너머바다',
#  '세화해수욕장',
#  '제주도 성산일출봉 근처',
#  '가치 Kachi',
#  '고집돌우럭-gozipfish',
#  '그라빠',
#  '카페 글렌코',
#  '제주시 이도이동 어딘가',
#  '드르쿰다인성산',
#  '김녕 성세기 해변',
#  '순천미향',
#  '바다위에코끼리',
#  '연태만',
#  '망오름',
#  '우드노트',
#  '보롬왓',
#  '서부농업기술센터',
#  '제주센트럴시티',
#  'Sheep',
#  '사쿠라미치 - 벚꽃길',
#  'M1971 요트투어',
#  '카페바나나 중문점',
#  '동도원',
#  '탑동바닷가',
#  '홍찜닭',
#  '제주한라병원',
#  '세화숲',
#  'CAFE COLA Coffee&coke',
#  '자구리문화예술공원',
#  '온에어',
#  '쿠쿠아림',
#  '디아일랜드블루호텔',
#  '안녕, 육지사람',
#  '곤트란쉐리에 제주 Gontran Cherrier Jeju',
#  '제주관광공사 지정면세점 / JTO Duty Free',
#  'Road129',
#  '제주도 금호리조트',
#  '서귀포 신시가지',
#  '자매국수 본점',
#  '다정한식탁',
#  '산방산',
#  '제주바다',
#  '우도근고기',
#  '탱테일',
#  '제주 비자림숲',
#  '제주아쿠아리움',
#  '이호태우등대',
#  '뽀로로앤타요 테마파크 제주',
#  '평대리 해변',
#  '삼양검은모래해변',
#  '높은오름',
#  '마틸다',
#  '해적중식당',
#  'Flat 4 Coffee Roasters',
#  '미쎄스 올리브',
#  '제주도 한경면',
#  '제노테카',
#  'LOTTE HOTEL JEJU 롯데호텔제주',
#  '이호테우 목마등대',
#  '월령리 선인장군락 (Cactus Colony of Wollyeong-ri)',
#  '협재',
#  '오르다카페',
#  '서귀포 기억나는집',
#  'Townhall Station',
#  '우도 서빈백사 해수욕장',
#  '그럼외도',
#  '카페두갓',
#  '순심이네한라봉돼지갈비',
#  'Dongmun Market Place',
#  '숙성도 중문점',
#  '우진해장국',
#  '조천읍',
#  '제주Island',
#  '소노캄 제주',
#  '강정천',
#  '지호네민박',
#  '그러므로part.2',
#  '협재해변',
#  'All that JEJU (올댓제주)',
#  '아라리오뮤지엄 제주',
#  '제주시 종로3가감자탕',
#  '그리다앤쿡',
#  '애월해변',
#  '김녕 앞바다',
#  '제주 해거름 전망대 Cafe',
#  '아꼼헤어',
#  'the cliff jeju - 더클리프 제주',
#  '도두봉 Dodu-Dong Rainbow Coastal Road',
#  '남원 큰엉해안',
#  '탐나돈',
#  '합성동어느곳',
#  '오드랑베이커리',
#  '유소바',
#  '제주 성아시',
#  '서귀포시 남원읍 하례리',
#  '닭머르',
#  'Bonte museum',
#  '성산보말죽칼국수 성산점',
#  '애향운동장',
#  '한라산 윗세오름',
#  '휘도명가',
#  'Busan 釜山, South Korea',
#  'Jeremy aewol',
#  'Iho Tewoo Beach 이호테우해변',
#  '클랭블루제주',
#  '바램목장&카페',
#  '카페차롱',
#  '영남알프스',
#  '비자림',
#  '제주써니하우스',
#  '하와이안비치카페',
#  'Seogwipo Heukdon',
#  '제주뚝배기',
#  '성이시돌목장',
#  '이호빨간등대매점',
#  '한라닭강정',
#  '마시안해변',
#  '사랑받는 중',
#  '여유로이',
#  '애플망고1947',
#  '이응게스트하우스',
#  '명진전복',
#  'Pizzeria Mano',
#  '평대홀라인',
#  '천연불맛 불쇼 미온당',
#  '송악산 둘레길',
#  '애월하미',
#  '유루유루',
#  '첨성대',
#  '타무라',
#  '물질식육식당',
#  '마레벤또',
#  '오설록티뮤지엄',
#  '제주시동문시장',
#  'HOTEL Toscana',
#  '논짓물식당',
#  '카페, 그 해 여름',
#  '조천수산',
#  '디앤디파트먼트 제주',
#  '제주유리박물관',
#  '전주도',
#  'Jeju Isand',
#  '독서의입구',
#  '돈이랑 본점',
#  '블루모모']

# %% [markdown]
# > 카카오 검색 API

# %%
# 사용 예시
import requests

searching = '합정 스타벅스'
url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
headers = {
    "Authorization": "KakaoAK 카카오API키입력자리"  # 카카오 API키 입력
}
places = requests.get(url, headers = headers).json()['documents']
# requests.get()으로 url 주소에 정보를 요청(headers에 저장된 아이디와 패스워드를 함께 전달)
# 요청 받은 후 결과를 json 형태로 불러옴
# documents 항목의 값을 선택함

places
# Out:
# [{'address_name': '서울 마포구 서교동 395-166',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '26572121',
#   'phone': '',
#   'place_name': '스타벅스 서교점',
#   'place_url': 'http://place.map.kakao.com/26572121',
#   'road_address_name': '서울 마포구 양화로 78',
#   'x': '126.916980454434',
#   'y': '37.5514601750423'},
#  {'address_name': '서울 마포구 합정동 472',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '2057327896',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 합정점',
#   'place_url': 'http://place.map.kakao.com/2057327896',
#   'road_address_name': '서울 마포구 월드컵로1길 14',
#   'x': '126.91211392586314',
#   'y': '37.54981773755399'},
#  {'address_name': '서울 마포구 서교동 490',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '288597324',
#   'phone': '',
#   'place_name': '스타벅스 합정폴리스R점',
#   'place_url': 'http://place.map.kakao.com/288597324',
#   'road_address_name': '서울 마포구 양화로 45',
#   'x': '126.91340049045',
#   'y': '37.5508989849269'},
#  {'address_name': '서울 마포구 서교동 490',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '27076117',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 합정메세나몰점',
#   'place_url': 'http://place.map.kakao.com/27076117',
#   'road_address_name': '서울 마포구 양화로 45',
#   'x': '126.913541853312',
#   'y': '37.5500016943689'},
#  {'address_name': '서울 마포구 서교동 475-13',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '12776689',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 망원역점',
#   'place_url': 'http://place.map.kakao.com/12776689',
#   'road_address_name': '서울 마포구 월드컵로 74',
#   'x': '126.91071941264',
#   'y': '37.5557803955969'},
#  {'address_name': '서울 마포구 서교동 374-20',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '27416913',
#   'phone': '',
#   'place_name': '스타벅스 서교동사거리',
#   'place_url': 'http://place.map.kakao.com/27416913',
#   'road_address_name': '서울 마포구 양화로 105',
#   'x': '126.918607875358',
#   'y': '37.5534723352988'},
#  {'address_name': '서울 마포구 서교동 353-5',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '1436512690',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 홍대입구역사거리R점',
#   'place_url': 'http://place.map.kakao.com/1436512690',
#   'road_address_name': '서울 마포구 양화로 125',
#   'x': '126.920317785646',
#   'y': '37.5546231745866'},
#  {'address_name': '서울 마포구 동교동 205-6',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '20705154',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 동교점',
#   'place_url': 'http://place.map.kakao.com/20705154',
#   'road_address_name': '서울 마포구 월드컵북로 22',
#   'x': '126.919993980608',
#   'y': '37.5568646370831'},
#  {'address_name': '서울 마포구 상수동 86-22',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '17127074',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 홍대삼거리점',
#   'place_url': 'http://place.map.kakao.com/17127074',
#   'road_address_name': '서울 마포구 와우산로 64',
#   'x': '126.92326479924',
#   'y': '37.5501958209348'},
#  {'address_name': '서울 마포구 동교동 159-1',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '22105109',
#   'phone': '',
#   'place_name': '스타벅스 홍대역점',
#   'place_url': 'http://place.map.kakao.com/22105109',
#   'road_address_name': '서울 마포구 양화로 165',
#   'x': '126.923637798148',
#   'y': '37.5572887166274'},
#  {'address_name': '서울 마포구 서교동 343-10',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '7962302',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 홍대갤러리점',
#   'place_url': 'http://place.map.kakao.com/7962302',
#   'road_address_name': '서울 마포구 와우산로 101',
#   'x': '126.924809884926',
#   'y': '37.5531989403216'},
#  {'address_name': '서울 마포구 상수동 329-1',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '26848996',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 상수역점',
#   'place_url': 'http://place.map.kakao.com/26848996',
#   'road_address_name': '서울 마포구 독막로 88',
#   'x': '126.923272022704',
#   'y': '37.5475649101839'},
#  {'address_name': '서울 마포구 동교동 166-1',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '231272664',
#   'phone': '',
#   'place_name': '스타벅스 홍대공항철도역점',
#   'place_url': 'http://place.map.kakao.com/231272664',
#   'road_address_name': '서울 마포구 양화로 178',
#   'x': '126.92518582665798',
#   'y': '37.557509550972256'},
#  {'address_name': '서울 마포구 창전동 130',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '1572099327',
#   'phone': '',
#   'place_name': '스타벅스 서강광흥창역점',
#   'place_url': 'http://place.map.kakao.com/1572099327',
#   'road_address_name': '서울 마포구 서강로 69',
#   'x': '126.931657893743',
#   'y': '37.5493756625598'},
#  {'address_name': '서울 마포구 노고산동 54-1',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '1132693025',
#   'phone': '',
#   'place_name': '스타벅스 신촌오거리점',
#   'place_url': 'http://place.map.kakao.com/1132693025',
#   'road_address_name': '서울 마포구 신촌로16길 10',
#   'x': '126.934699199575',
#   'y': '37.5551906225976'}]

# %%
# 장소 검색 함수 만들기
def find_places(searching):
    
    # 1. 접속 url 만들기
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
    
    # 2. headers 입력하기
    headers = {
    "Authorization": "KakaoAK 카카오API키입력자리"  # 카카오 API키 입력
    }
    
    # 3. API 요청 & 정보 받기
    places = requests.get(url, headers = headers).json()['documents']
    
    # 4. 필요한 정보 선택하기
    place = places[0] 
    name = place['place_name']
    x=place['x']
    y=place['y']
    data = [name, x, y, searching]  # 지도상의 명칭, 경도, 위도, 검색어

    return data

# %%
# 제주공항 검색 예
data = find_places('제주공항')
data
# Out:
# ['제주국제공항', '126.492769004244', '33.5070789578184', '제주공항']

# %%
# 인스타그램 위치명에 대한 위치정보 검색
from tqdm import tqdm_notebook  # 검색 시 현재 작업 진행상황 확인 
import time
locations_inform = [] 
for location in tqdm_notebook(locations):
    try:
        data = find_places(location)
        locations_inform.append(data)
        time.sleep(0.5)
    except:
        pass
locations_inform
# Out:
# /Users/nani/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# HBox(children=(FloatProgress(value=0.0, max=385.0), HTML(value='')))
# [['Jeju in aA', '126.83650369902168', '33.53833652360498', 'Jeju'],
#  ['제주도', '126.545875710283', '33.3797769227161', '제주도'],
#  ['협재해수욕장', '126.239157539085', '33.3938660776221', '제주 협재 해수욕장'],
#  ['푸른섬게스트하우스', '126.812424476454', '33.3079427982969', '푸른섬 제주도'],
#  ['제주도', '126.545875710283', '33.3797769227161', 'Jeju Island'],
#  ['제주도', '126.545875710283', '33.3797769227161', '제주도 Jeju Island'],
#  ['서귀포잠수함', '126.558616052674', '33.2393033784206', 'Seogwipo'],
#  ['올레길 17코스(광령-제주원도심 올레)', '126.439341083568', '33.4608856490895', '제주도 애월읍'],
#  ['곽지해수욕장', '126.304673157235', '33.4506575078278', '제주도 곽지해수욕장'],
#  ['안돌오름', '126.755820481231', '33.4578484860019', '안돌오름'],
#  ['고래배꼽', '126.403430604615', '33.4804484298816', '고래배꼽'],
#  ['카페모알보알제주', '126.727953094591', '33.5595665887276', '모알보알'],
#  ['한담해안산책로', '126.310468326159', '33.4593234504188', '한담해안산책로'],
#  ['새별오름', '126.357711941768', '33.3661936453469', '새별오름'],
#  ['금오름', '126.305717639727', '33.3545500138779', '금악오름'],
#  ['사이카레', '126.381106668339', '33.4842446359284', '사이카레'],
#  ['아침미소목장', '126.58601792037048', '33.45475699821516', '제주 아침미소목장'],
#  ['광주경찰서', '127.239583690907', '37.408267273136', 'Gwangju'],
#  ['마노르블랑', '126.294990785554', '33.2548188842285', '카페 마노르블랑 제주'],
#  ['귀더크', '126.282366800118', '33.4423007490057', '제주귀더크'],
#  ['아카렌가', '126.264946704693', '33.4117413474751', '아카렌가'],
#  ['이호테우해수욕장', '126.452690819027', '33.4973768007144', '이호테우해변'],
#  ['용담해안도로', '126.471571926708', '33.5091289269459', '도두해안도로'],
#  ['D', '126.923721083602', '37.5510826987805', 'D&department JEJU by Arario'],
#  ['용눈이오름', '126.83251014664', '33.4596996808185', '용눈이오름'],
#  ['용머리해안', '126.314736627312', '33.2316567556941', '용머리해안'],
#  ['함덕해수욕장', '126.669238934013', '33.5430615661113', '제주 함덕 서우봉 해변'],
#  ['원앤온리', '126.319192490757', '33.2392223486155', 'One and only - 원앤온리 제주'],
#  ['월정리해수욕장', '126.795805057888', '33.556469394054', '월정리해변'],
#  ['제주시민속오일시장', '126.475483734929', '33.4972409685804', '제주시민속오일시장'],
#  ['사려니숲길', '126.62649730394567', '33.422032834994496', '사려니숲길'],
#  ['그계절', '126.818530919106', '33.5318587572743', '그계절'],
#  ['광치기해변', '126.92449048608', '33.452086460427', '광치기해변'],
#  ['올레길 7코스(서귀포-월평 올레)', '126.51531780746991', '33.237465168471545', '제주 서귀포'],
#  ['미남미녀', '128.815711636266', '35.9110205265075', '미남미녀'],
#  ['마녀상회', '126.19098189638305', '33.25746034468198', '마녀상회'],
#  ['곱을락', '129.082571495302', '35.2007424974117', '곱을락연어'],
#  ['서귀다원', '126.596916297423', '33.312119039434', '서귀다원'],
#  ['금능해수욕장', '126.235889902253', '33.3904488156321', '금능해수욕장'],
#  ['상효원수목원', '126.584635005756', '33.3059583755486', '상효원 수목원'],
#  ['우도', '126.955582257582', '33.5044199749505', '우도'],
#  ['허니문하우스', '126.578712696609', '33.244155324551', '허니문하우스'],
#  ['제주김만복 본점', '126.508921919644', '33.4970353986304', '제주김만복'],
#  ['젬스톤', '129.04479520748114', '35.094623591451665', '젬스톤'],
#  ['어디가손세차장', '126.94203094468874', '37.55759470684954', '합정 어딘가'],
#  ['하이엔드제주', '126.30917383944714', '33.46359065428745', '하이엔드 제주'],
#  ['오후새우시', '126.424190172164', '33.2515892389543', '오후새우시'],
#  ['제주신화월드',
#   '126.31725882345',
#   '33.3060022512072',
#   '제주신화월드 Jeju Shinhwa World'],
#  ['북촌에가면', '126.69258562150661', '33.54801196628197', '북촌에 가면'],
#  ['섭지코지', '126.930609241011', '33.4239380655993', '섭지코지 (Seopjikoji)'],
#  ['함덕해수욕장', '126.669238934013', '33.5430615661113', '함덕해수욕장'],
#  ['애월해안도로', '126.36867872098', '33.4781232943703', '애월해안도로'],
#  ['서귀포치유의숲', '126.527883051611', '33.2918779569778', '서귀포 치유의 숲'],
#  ['히든클리프호텔&네이쳐',
#   '126.402595131766',
#   '33.2547764885257',
#   'Hidden Cliff / 히든 클리프'],
#  ['울트라마린', '126.206069756519', '33.3694603786212', '울트라마린'],
#  ['도두봉', '126.468115685304', '33.5083099200904', '도두봉'],
#  ['모뉴에트', '126.902224926828', '33.4914819914411', '모뉴에트'],
#  ['큰엉해안경승지', '126.703714399015', '33.2733321532168', '큰엉해안경승지'],
#  ['랜디스도넛 제주직영점', '126.31142823728557', '33.46117162424217', '제주맛집'],
#  ['아부오름', '126.777214998455', '33.4485841755621', '아부오름'],
#  ['빛의 벙커',
#   '126.89981825080305',
#   '33.43964477102691',
#   '빛의 벙커 Bunker de Lumières'],
#  ['숙성도 노형점', '126.48503012387', '33.4850301883515', '숙성도'],
#  ['신창풍차해안도로', '126.17420604655737', '33.343081026740045', '신창풍차해안도로'],
#  ['드르쿰다', '126.91908094568531', '33.444502297886025', '드르쿰다'],
#  ['올레길 7코스(서귀포-월평 올레)', '126.51531780746991', '33.237465168471545', '제주도 서귀포'],
#  ['이너프라운지', '126.93565842163994', '37.5452225040192', 'Enough, 이너프'],
#  ['바다다', '126.436715016074', '33.2369068490562', 'Vadada 바다다'],
#  ['우도', '126.955582257582', '33.5044199749505', '제주도 우도'],
#  ['유주미시그룸', '127.44588809913247', '37.2825712656294', 'Cafe yuzu'],
#  ['베케', '126.60492258733058', '33.26190881355424', 'Veke'],
#  ['항파두리 항몽유적지', '126.407922584204', '33.4527478729655', '항파두리 항몽유적지'],
#  ['아줄레주', '126.839173835129', '33.366986353012', '아줄레주'],
#  ['별돈별', '126.180166851945', '33.3086616408909', '별돈별'],
#  ['미스틱3도', '126.487556300468', '33.4499469794883', '미스틱 3도'],
#  ['스위스스토어', '126.677279652552', '33.4943677447448', '제주시 조천읍 와산리'],
#  ['곽지해수욕장', '126.304673157235', '33.4506575078278', '곽지해수욕장'],
#  ['베케', '126.60492258733058', '33.26190881355424', '베케'],
#  ['성산일출봉', '126.940537521366', '33.4591349705437', 'Seongsan Ilchulbong'],
#  ['금오름', '126.305717639727', '33.3545500138779', '금오름'],
#  ['따라비오름', '126.752858386101', '33.3887069884228', '따라비오름'],
#  ['미미슈', '126.3301606120398', '33.44090739917092', '미미슈'],
#  ['올레길 14코스(저지-한림 올레)', '126.22633963633878', '33.37028420751925', '제주도 한림'],
#  ['제주도', '126.545875710283', '33.3797769227161', 'Jeju-Island'],
#  ['공백', '126.715093661443', '33.5533924123546', 'Gongbech.공백'],
#  ['옛날두부집', '127.00014576529675', '35.041039106274255', '월정길'],
#  ['골목', '126.66173332610069', '33.543888786453095', '함덕골목해장국'],
#  ['여름문구사', '126.858871425193', '33.521423891365', '여름문구사'],
#  ['제제댁게스트하우스', '126.64486253973615', '33.52992457189592', '제제댁'],
#  ['성읍녹차마을 영농조합법인', '126.789956909791', '33.3810863134031', '성읍녹차마을 영농조합법인'],
#  ['비밀의숲', '126.755874215783', '33.4532594088582', '비밀의숲'],
#  ['숨비나리', '126.348563304702', '33.2822496690083', '숨비나리'],
#  ['스튜디오쿠나', '126.428772852607', '33.2656792751451', '스튜디오 쿠나'],
#  ['일산해수욕장', '129.430898527988', '35.4957863011333', '울산'],
#  ['볼수록제주', '126.39338086539', '33.4682173887109', '볼수록 제주'],
#  ['명랑스낵', '126.258817154541', '33.4091714181718', '명랑스낵'],
#  ['함덕487', '126.662218166527', '33.5432517829153', '함덕487'],
#  ['산방산', '126.313425322789', '33.2413040368283', '제주 산방산'],
#  ['롱리브', '126.541524169251', '33.4765570711503', '𝐋𝐨𝐧𝐠𝐥𝐢𝐯𝐞 - 롱리브'],
#  ['인그리드', '126.45668314517829', '33.50255325983955', '인그리드'],
#  ['울산다찌', '128.414479176612', '34.8330103553239', '다찌'],
#  ['조안베어뮤지엄', '126.4340626860404', '33.24025246053814', 'Joanne Bear Museum'],
#  ['이중섭거리', '126.564181041217', '33.245652453492', '이중섭 거리'],
#  ['한담공원', '126.310861002602', '33.459722330998', '한담공원'],
#  ['보름우스테이', '126.61633637075457', '33.2569936969959', '보름우스테이'],
#  ['산굼부리', '126.693840600964', '33.4325741154168', '산굼부리'],
#  ['노리매', '126.287339303265', '33.283114676288', '노리매'],
#  ['삼미횟집', '126.46372600121651', '33.50459087943616', '제주도 삼미횟집'],
#  ['구쟁기가 김밥속에', '126.42529366874906', '33.254156753482626', '구쟁기가김밥속에'],
#  ['소봉식당', '126.303028679974', '33.2469480248677', '소봉식당'],
#  ['늘봄흑돼지', '126.472866637648', '33.4794793376608', '늘봄흑돼지'],
#  ['비자림', '126.80998754971', '33.4904083697986', '제주시 구좌읍 평대리'],
#  ['배곧신도시 호반베르디움', '126.73258195261', '37.3684617738417', '시흥배곧신도시'],
#  ['인손', '126.85568114083337', '33.522568853942126', '인손'],
#  ['연돈', '126.40716457908', '33.2588962209144', '연돈'],
#  ['풍림다방 송당점', '126.785708132282', '33.471878655079', '송당리 풍림다방'],
#  ['곽지횟집', '126.306042633946', '33.4499403053841', '곽지횟집'],
#  ['세화해변', '126.86025618946', '33.5251436596119', '세화해변'],
#  ['오라방', '126.9063734416044', '37.55314341374803', '오라방'],
#  ['알뜨르비행장', '126.271527320164', '33.2047161778831', '알뜨르비행장'],
#  ['진주역 (폐역)', '128.089214187665', '35.1784870091882', 'Jinju'],
#  ['금능상회', '126.22670411768', '33.3893208307401', '금능상회'],
#  ['귤밭상점', '126.300926977316', '33.2850275123927', '귤밭상점'],
#  ['제주도푸른밤', '126.464792497816', '33.5061678608435', '제주도푸른밤'],
#  ['골목카페옥수', '126.379977434507', '33.4397509795262', '골목카페 옥수'],
#  ['올레길 17코스(광령-제주원도심 올레)', '126.439341083568', '33.4608856490895', '제주 애월읍'],
#  ['아끈다랑쉬', '126.8313370397', '33.4744664240713', '아끈다랑쉬오름'],
#  ['올레길 7코스(서귀포-월평 올레)', '126.51531780746991', '33.237465168471545', '서귀포'],
#  ['윤네일', '126.90724250537', '35.1701254249031', '윤네일&김뷰티'],
#  ['연과자점', '126.559997555546', '33.2513865187395', '연 과자점'],
#  ['도두봉', '126.468115685304', '33.5083099200904', '제주도 도두봉'],
#  ['레이지펌프', '126.309539831628', '33.4662712983402', '레이지펌프'],
#  ['제주서귀포혁신도시LH2단지아파트', '126.52088919911156', '33.248730067465225', '서귀포혁신도시'],
#  ['돼지굽는정원', '126.241083771309', '33.3918691333548', '돼지굽는정원'],
#  ['모모샌드', '126.513406529757', '33.5086872236019', '모모샌드'],
#  ['도민상회 월정점', '126.800253673536', '33.5550232816655', '도민상회월정점'],
#  ['르미에르제주 풀빌라', '126.36006711511021', '33.475098488274675', '르미에르제주'],
#  ['정물오름', '126.329463365847', '33.3384913490549', '정물오름'],
#  ['산지해장국', '126.528510119738', '33.516340623989', '산지해장국'],
#  ['베이힐풀앤빌라',
#   '126.37266244396896',
#   '33.23690685314572',
#   '베이힐풀앤빌라 Bayhill Pool&Villa'],
#  ['인디고트리', '126.6348243522451', '33.26382963467241', 'Indigoterie'],
#  ['인생밥집', '126.264633925654', '33.4113518111306', '인생밥집'],
#  ['휴일로', '126.36652497979144', '33.232208057130535', '휴일로'],
#  ['봄플라워', '126.975392837188', '37.3030979749628', '봄이옵니다플라워'],
#  ['가시아방국수', '126.91807231222495', '33.438605089450014', '가시아방'],
#  ['홀리싯', '126.541303208187', '33.494800932172', '홀리싯'],
#  ['월령선인장군락지', '126.2154316324', '33.3778792539349', '제주 월령선인장 군락지'],
#  ['꼬지사께 제주모슬포점', '126.25342428170515', '33.22079108419403', '서귀포시 꼬지사께'],
#  ['백약이오름', '126.789758231167', '33.436809406991', '백약이 오름'],
#  ['카이로스', '126.400155234663', '33.449262850826', '카이로스 제주'],
#  ['램하우스', '126.673139339477', '33.4369211354646', '램하우스'],
#  ['다다의작은공간', '126.377840456271', '33.4414316635391', '다다의 작은공간'],
#  ['공간사진관', '126.69566624458686', '33.54892477519552', '공간사진관'],
#  ['Daejeon제일공인중개사사무소', '127.3701816330705', '36.34671554341633', 'Daejeon'],
#  ['한라산 성판악입구약수터', '126.619567953473', '33.3847274745335', '한라산 성판악 입구'],
#  ['형제해안도로', '126.293352563779', '33.2167542093081', '제주도 해안도로'],
#  ['제주레일바이크', '126.836945581676', '33.4646211629404', 'Jeju Rail Bike'],
#  ['무아시스', '126.540652851024', '33.4730664692874', 'Mooasis'],
#  ['추억속에하얀집', '128.204050049846', '38.0482780962419', '추억 속'],
#  ['하나의식탁', '126.528960340612', '33.4976108738619', '하나의식탁'],
#  ['그리운바다성산포', '126.930043379887', '33.4698550378572', '그리운바다성산포'],
#  ['서귀포매일올레시장', '126.56384869150997', '33.24991509958467', '서귀포 매일올레시장'],
#  ['두물머리', '127.315829778049', '37.5328127891601', '두물머리'],
#  ['에코랜드테마파크', '126.670278657345', '33.4483387252476', '에코랜드'],
#  ['새미은총의동산', '126.323748438182', '33.3480029205995', '새미은총의동산'],
#  ['토스카나호텔', '126.48440899034529', '33.26562309357885', '제주도 토스카나호텔'],
#  ['미친부엌', '126.52313770399789', '33.51699084178409', '미친부엌'],
#  ['레이지커피', '126.516668600018', '33.5011482662824', 'Lazzzy coffee'],
#  ['너와의첫여행', '126.384541975515', '33.4506360949443', '너와의첫여행'],
#  ['옛날아우내순대 제주점', '126.39683630583', '33.4824820499156', '아우내순대제주'],
#  ['노고로시', '126.27742602496217', '33.42365340997193', '노고로시'],
#  ['협재수우동 쇠소깍직영점', '126.61867504286916', '33.25076159560252', '쇠소깍 수우동'],
#  ['제주스쿠버스쿨', '126.528945195362', '33.2484308449102', '제주스쿠버스쿨'],
#  ['제마닭', '126.495538671751', '33.4845396659718', '제마닭'],
#  ['문쏘', '126.25670970996777', '33.405687697267794', '문쏘'],
#  ['세러데이아일랜드', '126.844061368668', '33.5325246531532', 'Saturdayisland'],
#  ['함덕해수욕장', '126.669238934013', '33.5430615661113', '제주도 함덕해수욕장'],
#  ['함덕북촌마을길', '126.677533908169', '33.5488211775575', '서우봉 둘레길'],
#  ['한남리머체왓숲길', '126.6663210996524', '33.332348080994805', '머체왓숲길'],
#  ['제주제트', '126.933105663363', '33.47190157608501', '제주제트'],
#  ['성이시돌목장', '126.327321076199', '33.3477698762559', 'Jeju, Korea'],
#  ['올레길 20코스(김녕-하도 올레)', '126.745210877984', '33.557569317545', '김녕'],
#  ['곽지해수욕장', '126.304673157235', '33.4506575078278', 'Gwakji Gwamul Beach'],
#  ['난산리사무소', '126.8707830334611', '33.40116944298222', '난산리사무소'],
#  ['페이스뮤직', '126.915848984951', '37.5512791744838', 'Seoul, Korea'],
#  ['함덕해수욕장', '126.669238934013', '33.5430615661113', '제주 함덕해변'],
#  ['소예르', '126.989640753801', '35.3182977872649', '담양소예르'],
#  ['선녀와나무꾼 테마공원', '126.703778647835', '33.4787929391846', '제주시 조천읍 선흘리'],
#  ['무주IC', '127.645942078315', '35.9772890900491', 'Muju'],
#  ['돌카롱', '126.657004943213', '33.4258382748368', '돌카롱'],
#  ['랜디스도넛 제주직영점', '126.31142823728557', '33.46117162424217', '랜디스도넛'],
#  ['썬샤인워크', '126.389289958486', '33.2480705257603', '썬샤인워크'],
#  ['김해국제공항', '128.946728737746', '35.1731997026519', '김해공항'],
#  ['새별오름', '126.357711941768', '33.3661936453469', '제주도 새별오름'],
#  ['김포국제공항 국내선', '126.802874569181', '37.5589508457596', '김포공항'],
#  ['와락게스트하우스', '126.854779361791', '33.5275536458884', '와락 게스트하우스'],
#  ['뱃도새기', '126.579877914553', '33.2553827694594', '뱃도새기'],
#  ['스누피가든', '126.77818357251392', '33.44412294466081', '스누피가든'],
#  ['폼포코식당', '126.91857470910176', '33.449921554718664', '폼포코식당'],
#  ['돌담너머바다 판포점', '126.198522679671', '33.3655601150569', '돌담너머바다'],
#  ['세화해변', '126.86025618946', '33.5251436596119', '세화해수욕장'],
#  ['그라빠', '126.796016814137', '33.5525099412805', '그라빠'],
#  ['카페글렌코', '126.73324152121354', '33.43367131314919', '카페 글렌코'],
#  ['어디가코', '126.527949409191', '33.499875433506', '제주시 이도이동 어딘가'],
#  ['드르쿰다', '126.91908094568531', '33.444502297886025', '드르쿰다인성산'],
#  ['김녕해수욕장', '126.759313988844', '33.5574388587079', '김녕 성세기 해변'],
#  ['순천미향', '126.3124867027795', '33.23565653706234', '순천미향'],
#  ['바다위에코끼리', '126.24293648929', '33.3978453589448', '바다위에코끼리'],
#  ['연태만', '126.52530869106884', '33.50812753060554', '연태만'],
#  ['느지리오름', '126.26159405812', '33.366567968017', '망오름'],
#  ['우드노트', '126.698573243357', '33.2726237344419', '우드노트'],
#  ['보롬왓', '126.75249576943', '33.4134970849722', '보롬왓'],
#  ['서부농업기술센터', '126.248682012763', '33.3536878632917', '서부농업기술센터'],
#  ['제주센트럴시티호텔', '126.487108864608', '33.4857636889032', '제주센트럴시티'],
#  ['SHEEP새끼', '126.974195447598', '37.5321618991232', 'Sheep'],
#  ['M1971', '126.25715797280067', '33.21004453995747', 'M1971 요트투어'],
#  ['카페바나나 중문점', '126.417180970208', '33.2580230162948', '카페바나나 중문점'],
#  ['동도원', '126.48964867356', '33.4908122702289', '동도원'],
#  ['바닷가식당', '126.528059624634', '33.5168437988784', '탑동바닷가'],
#  ['홍찜닭', '128.340120996715', '36.1134100214952', '홍찜닭'],
#  ['제주한라병원', '126.4850647711278', '33.48990253484053', '제주한라병원'],
#  ['카페세화숲', '126.861308065025', '33.5243694661041', '세화숲'],
#  ['자구리문화예술공원', '126.569401218069', '33.2437014730454', '자구리문화예술공원'],
#  ['온에어', '126.43040585816173', '33.48764199383085', '온에어'],
#  ['쿠쿠아림', '126.540569160151', '33.4740434900743', '쿠쿠아림'],
#  ['디아일랜드블루호텔', '126.565768270616', '33.245823905238', '디아일랜드블루호텔'],
#  ['안녕육지사람', '126.95717459279088', '33.51520614040171', '안녕, 육지사람'],
#  ['제주관광공사 지정면세점',
#   '126.424429045634',
#   '33.2413406944452',
#   '제주관광공사 지정면세점 / JTO Duty Free'],
#  ['로드129', '126.321048106969', '33.4643081022978', 'Road129'],
#  ['금호리조트 제주', '126.7018416620514', '33.27324562751031', '제주도 금호리조트'],
#  ['신시가지 횟집', '126.506076220117', '33.2530089473833', '서귀포 신시가지'],
#  ['자매국수 본점', '126.51700772779006', '33.516815625143686', '자매국수 본점'],
#  ['다정한식탁', '126.426296149705', '33.2583972011196', '다정한식탁'],
#  ['산방산', '128.538701442661', '34.8606897375716', '산방산'],
#  ['제주바다', '126.25107393538', '33.2181550644839', '제주바다'],
#  ['운산식당', '126.521912106387', '33.5159438800081', '우도근고기'],
#  ['탱테일', '126.48365633777', '33.4873505795764', '탱테일'],
#  ['비자림', '126.80998754971', '33.4904083697986', '제주 비자림숲'],
#  ['한화아쿠아플라넷 제주', '126.927879232127', '33.4330536347133', '제주아쿠아리움'],
#  ['이호테우등대', '126.451961352582', '33.5017949651276', '이호태우등대'],
#  ['뽀로로앤타요테마파크 제주',
#   '126.37082203402295',
#   '33.30041822583184',
#   '뽀로로앤타요 테마파크 제주'],
#  ['평대리해수욕장', '126.840859977641', '33.5335267644776', '평대리 해변'],
#  ['삼양해수욕장', '126.585537319057', '33.5258670153237', '삼양검은모래해변'],
#  ['높은오름', '126.793066793309', '33.4564484278964', '높은오름'],
#  ['마틸다', '126.334277144658', '33.4656961653476', '마틸다'],
#  ['해적', '126.84401655584709', '33.41822070465812', '해적중식당'],
#  ['플랏포커피', '126.482827857953', '33.4869828818394', 'Flat 4 Coffee Roasters'],
#  ['미쎄스올리브', '126.51165708335442', '33.24748417486678', '미쎄스 올리브'],
#  ['올레길 13코스(용수-저지 올레)', '126.21230336658091', '33.328625315540165', '제주도 한경면'],
#  ['제노테카', '126.490291584026', '33.4787840652356', '제노테카'],
#  ['롯데시티호텔 제주',
#   '126.486477218467',
#   '33.4906945837847',
#   'LOTTE HOTEL JEJU 롯데호텔제주'],
#  ['이호테우등대', '126.451961352582', '33.5017949651276', '이호테우 목마등대'],
#  ['협재해수욕장', '126.239157539085', '33.3938660776221', '협재'],
#  ['오르다카페', '128.571185189615', '35.83231082315', '오르다카페'],
#  ['기억나는집', '126.562188072497', '33.2450792298239', '서귀포 기억나는집'],
#  ['우도산호해변', '126.943047770114', '33.5024060741651', '우도 서빈백사 해수욕장'],
#  ['그럼외도', '126.43399937343', '33.4943031648662', '그럼외도'],
#  ['순심이네 한라봉돼지갈비', '126.331195410109', '33.24611811834', '순심이네한라봉돼지갈비'],
#  ['숙성도 중문지점', '126.407604356063', '33.2586116015878', '숙성도 중문점'],
#  ['우진해장국', '126.520003422855', '33.5115187080468', '우진해장국'],
#  ['함덕해수욕장', '126.669238934013', '33.5430615661113', '조천읍'],
#  ['휘닉스 제주', '126.928186733817', '33.4304968356285', '제주Island'],
#  ['소노캄 제주', '126.79202787301921', '33.30560666984461', '소노캄 제주'],
#  ['강정천', '126.489428214698', '33.2326659143234', '강정천'],
#  ['지호네민박 1호점', '126.35196103848028', '33.26055294474321', '지호네민박'],
#  ['그러므로 파트2', '126.485956399087', '33.4685648061968', '그러므로part.2'],
#  ['협재해수욕장', '126.239157539085', '33.3938660776221', '협재해변'],
#  ['아라리오뮤지엄 탑동시네마', '126.52331799642387', '33.51748109887348', '아라리오뮤지엄 제주'],
#  ['종로3가감자탕 연동점', '126.486445664776', '33.4891130613473', '제주시 종로3가감자탕'],
#  ['그리다앤쿡', '126.530652571894', '33.4975054978261', '그리다앤쿡'],
#  ['곽지해수욕장', '126.304673157235', '33.4506575078278', '애월해변'],
#  ['해거름전망대카페', '126.206255927757', '33.3701393836954', '제주 해거름 전망대 Cafe'],
#  ['아꼼헤어', '126.269035765091', '33.4269283986051', '아꼼헤어'],
#  ['큰엉해안경승지', '126.703714399015', '33.2733321532168', '남원 큰엉해안'],
#  ['탐나돈정육점식당', '126.430079401205', '33.2489259248305', '탐나돈'],
#  ['오드랑베이커리', '126.671581017399', '33.5421337502958', '오드랑베이커리'],
#  ['유소바', '126.91902016258139', '35.13876743832135', '유소바'],
#  ['성아시', '126.23038093523914', '33.38846013043346', '제주 성아시'],
#  ['쇠소깍', '126.624331997703', '33.252354866117', '서귀포시 남원읍 하례리'],
#  ['닭머르', '126.612087338359', '33.5355459503005', '닭머르'],
#  ['본태박물관', '126.39247966305703', '33.30377089594179', 'Bonte museum'],
#  ['성산보말죽칼국수 성산점', '126.917108468399', '33.4716827378313', '성산보말죽칼국수 성산점'],
#  ['제주종합경기장 애향운동장', '126.51782209543354', '33.49554666108122', '애향운동장'],
#  ['한라산 웃세붉은오름', '126.520701746978', '33.3603553396532', '한라산 윗세오름'],
#  ['휘도명가', '126.543267195744', '33.5019488062156', '휘도명가'],
#  ['이호테우해수욕장',
#   '126.452690819027',
#   '33.4973768007144',
#   'Iho Tewoo Beach 이호테우해변'],
#  ['클랭블루', '126.177301119874', '33.3448722920323', '클랭블루제주'],
#  ['바램목장&카페', '126.35259355146505', '33.31110694796215', '바램목장&카페'],
#  ['카페차롱', '126.35422582237', '33.2596450787665', '카페차롱'],
#  ['영남알프스', '129.067605227914', '35.5563262302399', '영남알프스'],
#  ['비자림', '126.80998754971', '33.4904083697986', '비자림'],
#  ['제주써니하우스', '126.28123094984', '33.4376311725396', '제주써니하우스'],
#  ['하와이안비치카페', '126.917472263396', '33.4351677419377', '하와이안비치카페'],
#  ['제주뚝배기', '126.653897854482', '37.414368216929', '제주뚝배기'],
#  ['성이시돌목장', '126.327321076199', '33.3477698762559', '성이시돌목장'],
#  ['이호빨간등대매점', '126.45322740292', '33.501376812332', '이호빨간등대매점'],
#  ['한라닭강정', '126.51659368256468', '33.511333246057596', '한라닭강정'],
#  ['마시안해변', '126.416892933344', '37.4320840360107', '마시안해변'],
#  ['여유로이', '126.83964340335886', '33.53354863677302', '여유로이'],
#  ['애플망고1947', '126.59954227021387', '33.28641319109263', '애플망고1947'],
#  ['이응게스트하우스', '126.366006321774', '33.2345036467401', '이응게스트하우스'],
#  ['명진전복', '126.850184971014', '33.5324709034017', '명진전복'],
#  ['핏제리아마노', '126.429191724439', '33.4844249480885', 'Pizzeria Mano'],
#  ['홀라인 제주평대점', '126.839594157238', '33.5333989077066', '평대홀라인'],
#  ['송악산둘레길', '126.293075154019', '33.1968232389213', '송악산 둘레길'],
#  ['애월하미', '126.309145685482', '33.4638853152952', '애월하미'],
#  ['유루유루', '129.1575591981059', '35.167330448417374', '유루유루'],
#  ['첨성대', '129.219020190172', '35.8347180469201', '첨성대'],
#  ['타무라', '126.656880547466', '33.4989291238122', '타무라'],
#  ['물질식육식당', '126.48026288278535', '33.23536530227254', '물질식육식당'],
#  ['마레벤또', '126.311651375914', '33.4626081855416', '마레벤또'],
#  ['오설록티뮤지엄', '126.289443017025', '33.3059265460649', '오설록티뮤지엄'],
#  ['동문재래시장', '126.52601736630041', '33.51158874635444', '제주시동문시장'],
#  ['포커스', '126.389149989117', '33.243819598071', '논짓물식당'],
#  ['카페그해여름', '126.227965878653', '33.3370075151977', '카페, 그 해 여름'],
#  ['조천수산', '126.640784929173', '33.5475569640851', '조천수산'],
#  ['디앤디파트먼트 제주', '126.523314612444', '33.5177055816553', '디앤디파트먼트 제주'],
#  ['제주유리박물관', '126.370157858943', '33.2785417246746', '제주유리박물관'],
#  ['전주도', '126.29200896286757', '33.44296835070193', '전주도'],
#  ['정직한돈 본점', '126.338881485019', '33.4673580858876', '돈이랑 본점'],
#  ['블루모모', '126.532278740274', '33.4976775399288', '블루모모']]

# %%
# 위치 정보 저장
locations_inform_df = pd.DataFrame(locations_inform)
locations_inform_df.columns = ['name_official', '경도', '위도', '인스타위치명']
locations_inform_df.to_excel('./data/jeju_locations.xlsx', index=False)

# %% [markdown]
# > 위치 정보별 인스타 게시량 정리

# %%
location_counts_df = pd.read_excel('./data/jeju_location_counts.xlsx', index_col=0)
locations_inform_df = pd.read_excel('./data/jeju_locations.xlsx')

# %%
# 위치 데이터 병합
location_data = pd.merge(locations_inform_df, location_counts_df,
                        how = 'inner', left_on = 'name_official', right_index = True)
# inner: 양쪽에 모두 있는 데이터만 포함
# left_on: 왼쪽에 위치한 locations_inform_df에서 name_official을 기준으로 병합
# right_index: 오른쪽에 위치한 location_counts_df에서는 인덱스 기준으로 병합

location_data.head()
# Out:
#    name_official          경도         위도           인스타위치명  place
# 1            제주도  126.545876  33.379777              제주도     40
# 4            제주도  126.545876  33.379777      Jeju Island     40
# 5            제주도  126.545876  33.379777  제주도 Jeju Island     40
# 82           제주도  126.545876  33.379777      Jeju-Island     40
# 8         곽지해수욕장  126.304673  33.450658       제주도 곽지해수욕장      2

# %%
location_data.to_excel('./data/jeju_location_inform.xlsx', index = False)

# %% [markdown]
# > folium을 이용한 지도 시각화(개별 표시)

# %%
location_data = pd.read_excel('./data/jeju_location_inform.xlsx')
location_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 5 columns):
# name_official    171 non-null object
# 경도               171 non-null float64
# 위도               171 non-null float64
# 인스타위치명           171 non-null object
# place            171 non-null int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 6.8+ KB

# %%
# 지도 표시
import folium

Mt_Hanla = [33.362500, 126.533694]  # 한라산 좌표 중심
map_jeju = folium.Map(location = Mt_Hanla, zoom_start = 11)

for i in range(len(location_data)):
    name = location_data['name_official'][i]  # 공식명칭
    count = location_data['place'][i]  # 게시글 갯수
    size = int(count)*2
    long = float(location_data['위도'][i])
    lat = float(location_data['경도'][i])
    folium.CircleMarker((long, lat), radius = size, color = 'red', popup = name).add_to(map_jeju)
    # 원을 생성함: 원 위치(경도, 위도), 크기, 색상, 원 이름 등 정보 지정
    # 원을 map_jeju 지도에 추가함
    
map_jeju
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 지도 저장
map_jeju.save('./data/jeju.html')

# %% [markdown]
# > folium을 이용한 지도 시각화(그룹 표시)

# %%
from folium.plugins import MarkerCluster

locations = []
names = []

for i in range(len(location_data)):
    data = location_data.iloc[i]  # 행 하나씩
    locations.append((float(data['위도']), float(data['경도'])))  # 위도, 경도 순으로
    names.append(data['name_official'])
    
icon_create_function = """
function(cluster){
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(30, 30)
    }); 
}
"""

Mt_Hanla = [33.362500, 126.533694]  # 한라산 좌표 중심
map_jeju2 = folium.Map(location = Mt_Hanla, zoom_start = 11)

marker_cluster = MarkerCluster(
    locations = locations, popups = names, 
    name = 'Jeju', 
    overlay = True, 
    control = True,
    icon_create_function = icon_create_function
)

marker_cluster.add_to(map_jeju2)
folium.LayerControl().add_to(map_jeju2)

map_jeju2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 지도 저장
map_jeju2.save('./data/jeju_cluster.html')
